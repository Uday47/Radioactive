# %%
import cv2
cv2.__version__
# Out:
# '4.0.1'

# %%
import numpy as np
import cv2

# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades

#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier(r'C:\Users\Uday\Desktop\Misc\Datasets\haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(0)

while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))
    if len(faces) == 1:
        for (x,y,w,h) in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
    elif len(faces) > 1:
        for (x,y,w,h) in faces:
            label = "Warning : Multiple people in the frame."
            cv2.putText(img, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 0), 1)
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            #print ("multiple")

    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff 
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import time 

a = True 

x = int(time.time())


        
        
        
import numpy as np
import cv2

# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades

#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier(r'C:\Users\Uday\Desktop\Misc\Datasets\haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(0)

while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))
    if len(faces) == 1:
        for (x,y,w,h) in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
    elif len(faces) > 1:
        for (x,y,w,h) in faces:
            label = "Warning : Multiple people in the frame."
            cv2.putText(img, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 0, 0), 2)
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            print ("multiple")

    cv2.imshow('img',img)
    k = cv2.waitKey(30) & 0xff 
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
from matplotlib.pyplot import imshow
# %matplotlib inline
model = load_model(r'C:\Users\Uday\Downloads\_mini_xception.100_0.65.hdf5')

# prevents openCL usage and unnecessary logging messages
cv2.ocl.setUseOpenCL(False)

# dictionary which assigns each label an emotion (alphabetical order)
emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

# start the webcam feed
cap = cv2.VideoCapture(0)
while True:
    # Find haar cascade to draw bounding box around face
    ret, frame = cap.read()
    if not ret:
        break
    facecasc = cv2.CascadeClassifier(r'C:\Users\Uday\Desktop\Misc\Datasets\haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = facecasc.detectMultiScale(gray,scaleFactor=1.3, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (255, 0, 0), 2)
        roi_gray = gray[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
        prediction = model.predict(cropped_img)
        maxindex = int(np.argmax(prediction))
        cv2.putText(frame, emotion_dict[maxindex], (x+20, y-60), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow('Video', cv2.resize(frame,(1600,960),interpolation = cv2.INTER_CUBIC))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-8f1e129136d6> in <module>
#       1 import numpy as np
# ----> 2 from matplotlib.pyplot import imshow
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 model = load_model(r'C:\Users\Uday\Downloads\_mini_xception.100_0.65.hdf5')
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import tensorflow as tf
tf.__version__
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-4ae80da9abf6> in <module>
# ----> 1 import tensorflow as tf
#       2 tf.__version__
#
# ~\Anaconda\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
# ...

# %%
# !pip install pillow

# %%
import zipfile

# %%
from PIL import Image
from zipfile import ZipFile

# %%
zip_path = "U:\MachineLearning\DAiSEE.zip"
with ZipFile(zip_path) as myzip:
    files_in_zip = myzip.namelist()

# %%
files_in_zip
# Out:
# ['DAiSEE/',
#  'DAiSEE/hog.py',
#  'DAiSEE/extractFrames.py',
#  'DAiSEE/README.txt',
#  'DAiSEE/GenderClips/',
#  'DAiSEE/GenderClips/Males',
#  'DAiSEE/GenderClips/Females',
#  'DAiSEE/Labels/',
#  'DAiSEE/Labels/ValidationLabels.csv',
#  'DAiSEE/Labels/TrainLabels.csv',
#  'DAiSEE/Labels/TestLabels.csv',
#  'DAiSEE/Labels/AllLabels.csv',
#  'DAiSEE/DataSet/',
#  'DAiSEE/DataSet/Validation.txt',
#  'DAiSEE/DataSet/Train.txt',
#  'DAiSEE/DataSet/Test.txt',
#  'DAiSEE/DataSet/Train/',
#  'DAiSEE/DataSet/Validation/',
#  'DAiSEE/DataSet/Test/',
#  'DAiSEE/DataSet/Train/110013/',
#  'DAiSEE/DataSet/Train/310070/',
#  'DAiSEE/DataSet/Train/342227/',
#  'DAiSEE/DataSet/Train/210057/',
#  'DAiSEE/DataSet/Train/310064/',
#  'DAiSEE/DataSet/Train/240846/',
#  'DAiSEE/DataSet/Train/110008/',
#  'DAiSEE/DataSet/Train/110007/',
#  'DAiSEE/DataSet/Train/110002/',
#  'DAiSEE/DataSet/Train/248510/',
#  'DAiSEE/DataSet/Train/310080/',
#  'DAiSEE/DataSet/Train/110011/',
# ...

# %%
with ZipFile(zip_path) as myzip:
    with myzip.open(files_in_zip[12]) as myfile:
        img = Image.open(myfile)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-a9de3027f58d> in <module>
#       1 with ZipFile(zip_path) as myzip:
#       2     with myzip.open(files_in_zip[12]) as myfile:
# ----> 3         img = Image.open(myfile)
#
# ~\Anaconda\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2816     for message in accept_warnings:
#    2817         warnings.warn(message)
# -> 2818     raise IOError("cannot identify image file %r" % (filename if filename else fp))
#    2819
#    2820
#
# OSError: cannot identify image file <zipfile.ZipExtFile name='DAiSEE/DataSet/' mode='r'>

# %%
DATASET_DIR = "U:\MachineLearning\DAiSEE.zip"

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
normal_images = []
for img_path in glob.glob('U:\MachineLearning\DAiSEE.zip\DAiSEE\DataSet\Test\*'):
    print(img_path.namelist())

# %%
fig = plt.figure()
fig.suptitle('normal')
plt.imshow(normal_images[0], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-51ea9886ad9d> in <module>
#       1 fig = plt.figure()
#       2 fig.suptitle('normal')
# ----> 3 plt.imshow(normal_images[0], cmap='gray')
#
# IndexError: list index out of range

# %%
import os

# %%
path = "U:\MachineLearning\DAiSEE.zip\DAiSEE\DataSet"
dataset = path.namelist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-7e9ab32ccbd0> in <module>
#       1 path = "U:\MachineLearning\DAiSEE.zip\DAiSEE\DataSet"
# ----> 2 dataset = path.namelist()
#
# AttributeError: 'str' object has no attribute 'namelist'

# %%
len(dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-8f70883cce9f> in <module>
# ----> 1 len(dataset)
#
# TypeError: object of type 'ZipFile' has no len()

# %%
import zipfile

from PIL import Image

imgzip = open('U:\MachineLearning\DAiSEE.zip', 'rb')
z = zipfile.ZipFile(imgzip)
os.listdir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-833c5ed548b8> in <module>
#       5 imgzip = open('U:\MachineLearning\DAiSEE.zip', 'rb')
#       6 z = zipfile.ZipFile(imgzip)
# ----> 7 z.listdir()
#
# AttributeError: 'ZipFile' object has no attribute 'listdir'

# %%
# !pip install StringIO
# Out:
# ERROR: Could not find a version that satisfies the requirement StringIO (from versions: none)
# ERROR: No matching distribution found for StringIO

# %%
os.listdir("U:\MachineLearning\DAiSEE.zip")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-55-1bfd9630c191> in <module>
# ----> 1 os.listdir("U:\MachineLearning\DAiSEE.zip")
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'U:\\MachineLearning\\DAiSEE.zip'

# %%
import os
from zipfile import ZipFile
zip_file = 'U:\MachineLearning\DAiSEE'
with ZipFile(zip_file, "r") as z:
    print(z.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-a9912bc6fd25> in <module>
#       2 from zipfile import ZipFile
#       3 zip_file = 'U:\MachineLearning\DAiSEE'
# ----> 4 with ZipFile(zip_file, "r") as z:
#       5     print(z.listdir())
#
# ~\Anaconda\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'U:\\MachineLearning\\DAiSEE'

# %%
# !cd desktop

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E0BD-0A76
#
#  Directory of C:\Users\Uday
#
# 22-10-2020  19:06    <DIR>          .
# 22-10-2020  19:06    <DIR>          ..
# 24-08-2019  14:37    <DIR>          .AndroidStudio3.5
# 04-09-2020  12:48               109 .bash_history
# 12-09-2020  12:48    <DIR>          .conda
# 12-09-2020  10:51                43 .condarc
# 20-08-2020  19:22    <DIR>          .config
# 09-10-2019  15:34    <DIR>          .configprops
# 09-10-2019  15:34    <DIR>          .datastorage
# 23-08-2019  20:08                16 .emulator_console_auth_token
# 04-09-2020  11:49                80 .gitconfig
# 24-08-2019  15:25    <DIR>          .gradle
# 08-05-2020  06:34                 0 .hdfview3.1.0
# 29-05-2019  17:13    <DIR>          .idlerc
# 29-09-2020  20:32    <DIR>          .ipynb_checkpoints
# 04-03-2020  21:14    <DIR>          .ipython
# 05-05-2020  10:04    <DIR>          .julia
# 20-08-2020  19:24    <DIR>          .jupyter
# ...

# %%
import os
files = [f for f in os.listdir('C:\misc\DAiSEE\ExtractedFaces\Test') if os.path.isfile(f)]

# %%
print (files)
# Out:
# []

# %%
import os
for subdir, dirs, files in os.walk('C:\misc\DAiSEE\ExtractedFaces\Test\907001'):
    for file in dirs:
        print(file)
# Out:
# 907001100
# 9070011010
# 9070011020
# 9070011060
# 9070011090
# 907001110
# 9070011110
# 907001120
# 907001150
# 907001160
# 907001170
# 907001180
# 907001210
# 907001220
# 907001240
# 907001270
# 907001280
# 907001310
# 907001340
# 907001350
# 907001360
# 907001370
# 907001400
# 907001430
# 907001450
# 907001480
# 907001490
# 90700150
# 907001500
# 907001520
# 907001550
# 907001560
# 907001570
# 907001580
# 90700160
# 907001600
# 907001620
# 907001650
# 907001670
# 907001680
# 90700170
# 907001730
# 907001740
# 907001780
# 907001790
# 90700180
# 907001820
# 907001840
# 907001850
# 907001860
# 90700190
# 907001910
# 907001940
# 907001950
# 907001970

# %%
# !cd "C:\misc\DAiSEE\ExtractedFaces\Test\907001"

# %%
# !cd desktop

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E0BD-0A76
#
#  Directory of C:\Users\Uday
#
# 26-10-2020  17:44    <DIR>          .
# 26-10-2020  17:44    <DIR>          ..
# 24-08-2019  14:37    <DIR>          .AndroidStudio3.5
# 04-09-2020  12:48               109 .bash_history
# 12-09-2020  12:48    <DIR>          .conda
# 12-09-2020  10:51                43 .condarc
# 20-08-2020  19:22    <DIR>          .config
# 09-10-2019  15:34    <DIR>          .configprops
# 09-10-2019  15:34    <DIR>          .datastorage
# 23-08-2019  20:08                16 .emulator_console_auth_token
# 04-09-2020  11:49                80 .gitconfig
# 24-08-2019  15:25    <DIR>          .gradle
# 08-05-2020  06:34                 0 .hdfview3.1.0
# 29-05-2019  17:13    <DIR>          .idlerc
# 29-09-2020  20:32    <DIR>          .ipynb_checkpoints
# 04-03-2020  21:14    <DIR>          .ipython
# 05-05-2020  10:04    <DIR>          .julia
# 20-08-2020  19:24    <DIR>          .jupyter
# ...
